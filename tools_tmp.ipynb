# %% [markdown]
# # 川普Agent

# %%
from google import genai
from google.genai.types import Tool, GenerateContentConfig, GoogleSearch
import os

client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))
model_id = "gemini-2.5-flash-preview-05-20"


google_search_tool = Tool(google_search=GoogleSearch())

response = client.models.generate_content(
    model=model_id,
    contents=(
        "查询一下特朗普的最新动态，2025年5月26日发生的以下内容：\n"
        "1. 特朗普的言论和在各社交平台发的帖子\n"
        "2. 特朗普的最新活动和行程\n"
        "3. 特朗普的最新新闻报道\n"
        "4. 特朗普正负的最新政策。\n"
        "都查询好之后分析所有内容对于美股市场的直接或者潜在影响，可以具体到行业、公司等，"
        "最终给出对未来一周的美股市场是利好还是利空，并给出置信度以及分析的逻辑。输出格式为json，包含以下字段：\n"
        "1.最新动态（所有内容的简短总结，4种类型，每种类型不超过3条） "
        "2. 影响方向（利好/利空,可以是多个行业或者公司） "
        "3. 置信度（0-1之间的浮点数） "
        "4. 分析逻辑（文本）"
        "注意，日期必须严格检查，是发生在要求的5月26日当天时间范围之内的"
    ),
    config=GenerateContentConfig(
        tools=[google_search_tool],
        response_modalities=["TEXT"],
    ),
)

for each in response.candidates[0].content.parts:
    print(each.text)
# Example response:
# The next total solar eclipse visible in the contiguous United States will be on ...

# To get grounding metadata as web content.
# print(response.candidates[0].grounding_metadata.search_entry_point.rendered_content)
# Out:
# Donald Trump在2025年5月26日的最新动态总结如下：
#
# **1. 言论和在各社交平台发的帖子：**
# *   特朗普在“真实社交”上发帖，祝大家“阵亡将士纪念日快乐”，但也同时攻击政治对手为“人渣”，并指责“激进左翼分子”试图摧毁美国，以及抨击那些保护罪犯的“仇美法官”。
# *   特朗普强烈批评俄罗斯总统普京，称其“完全疯了”，并表示对俄罗斯近期对乌克兰城市发动的导弹和无人机袭击感到“不爽”，暗示可能考虑对俄罗斯实施更多制裁。他还批评了乌克兰总统泽连斯基的言论“毫无益处”。
# *   特朗普威胁将进一步削减哈佛大学的30亿美元拨款，如果哈佛不提交外国学生名单，他将考虑把这些拨款分配给全国各地的职业学校。他还指责哈佛大学“非常反犹太主义”。
#
# **2. 最新活动和行程：**
# *   2025年5月26日，特朗普在弗吉尼亚州阿灵顿国家公墓参加了阵亡将士纪念日悼念仪式，并敬献花圈，发表讲话缅怀阵亡将士。
# *   在讲话中，特朗普也夹杂了对前总统的攻击和关于上帝让他重返白宫的言论。
# *   有报道提及特朗普在当天早些时候曾搭乘专机离开新泽西州的莫里斯顿，并在登机前接受了媒体采访。
#
# **3. 最新新闻报道：**
# *   关于特朗普推迟对欧盟商品征收50%关税至7月9日的报道，此前他曾威胁从6月1日开始实施。
# *   关于特朗普威胁削减哈佛大学拨款，并要求哈佛提交外国学生名单的新闻持续发酵，此前美国国土安全部已取消哈佛大学招收国际学生的资质，但被联邦法官发布临时限制令。
# *   多家媒体报道了特朗普对普京的严厉批评，以及他可能考虑对俄罗斯追加制裁的消息。
#
# **4. 政策立场：**
# *   **贸易政策：** 特朗普同意推迟对欧盟商品征收50%关税，显示出其贸易政策的“反复无常和不可预测性”，但也有望在一定程度上提振市场信心，因为避免了立即的贸易战升级。他此前的贸易政策倾向于征收对等关税以促进国内制造业。
# *   **外交政策：** 对普京的强硬措辞及其考虑对俄罗斯追加制裁的表态，标志着美俄关系可能恶化。
# *   **教育/移民政策：** 继续对哈佛大学施压，威胁削减其拨款并要求提供外国学生名单，这是其更广泛的移民控制和对高等教育机构施压的一部分。
# *   **国内政策：** 其言论中包含对政治对手的攻击以及边境安全问题的提及，这些与他“让美国再次伟大”的竞选主张和强硬的移民立场相符。
#
# ---
#
# **对美股市场的直接或者潜在影响分析：**
#
# *   **贸易政策（利好）：** 特朗普推迟对欧盟商品征收50%关税的决定，短期内对市场是利好。原定的关税威胁可能引发金融市场震荡，而此次的推迟（甚至可能是取消，取决于后续谈判）减少了贸易战立即升级的风险，为市场提供了喘息空间。
#     *   **受影响行业/公司：** 欧盟进口商品相关的零售、汽车、制药等行业将暂时避免更高的成本压力，例如欧洲汽车制造商及其在美国的经销商可能受益。此前因关税担忧而受压的跨国公司（尤其是涉及欧洲市场的公司）将看到不确定性降低。
#
# *   **外交政策（不确定/潜在利空）：** 对俄罗斯的强硬言论及潜在的制裁威胁，可能加剧地缘政治紧张局势，尤其是在俄乌冲突背景下。虽然具体的制裁措施尚未公布，但若实施，可能会对全球能源市场、商品价格以及与俄罗斯有业务往来的公司产生负面影响。
#     *   **受影响行业/公司：** 能源公司（油气价格波动）、国防工业（若冲突升级，需求可能增加）、以及与俄罗斯有贸易往来的国际企业。
#
# *   **教育/移民政策（潜在利空/特定行业影响）：** 对哈佛大学的持续施压，包括削减拨款和对国际学生的限制，可能对美国高等教育体系的吸引力造成长期负面影响，并可能影响相关教育服务产业和科技人才流入。
#     *   **受影响行业/公司：** 教育服务提供商、住房租赁市场（特别是大学城附近）、以及依赖国际人才的科技和研发公司，如可能影响科技公司的未来人才储备。
#
# *   **政治言论（中性偏不确定）：** 特朗普的政治攻击言论，尽管具有煽动性，但通常已被市场部分消化，短期内不太可能直接导致大规模市场波动，但会增加整体政策和政治环境的不确定性。长期而言，这种两极分化的言论可能影响投资者信心。
#
# **未来一周美股市场是利好还是利空：**
#
# 综合来看，未来一周美股市场可能呈现**中性偏利好**的走势。
#
# *   **利好因素：** 特朗普推迟对欧盟关税的决定是短期内最具体的利好消息，它消除了一个迫在眉睫的贸易冲突风险，有助于稳定投资者情绪。阵亡将士纪念日假期后，市场通常有“回归正常”的趋势。
# *   **潜在利空/不确定因素：** 对俄罗斯潜在制裁的担忧以及哈佛大学政策的影响，虽然目前来看其市场影响力不如贸易政策直接，但仍需关注后续发展。特朗普的反复无常的政策风格也增加了市场的不确定性。
#
# **置信度：** 0.7
#
# **分析逻辑：**
#
# 置信度为0.7，表明我对这一判断有较高的信心，但并非绝对。其逻辑主要基于以下几点：
#
# 1.  **“坏消息未发生”即“好消息”：** 金融市场往往对潜在的负面事件（如贸易战）反应剧烈。特朗普此前威胁对欧盟征收50%关税，这无疑是一个重磅利空。现在将这一措施推迟，意味着最坏的情况暂时避免，市场会对此做出积极反应，视为不确定性下降的利好。这通常会提振风险偏好。
# 2.  **具体且可量化的利好：** 贸易关税的推迟是当天最直接且对经济有实际影响的政策调整。相比之下，对哈佛的威胁更多是长期政策方向的信号，短期内对大盘影响有限；而对俄罗斯的强硬措辞，虽然值得关注，但实际制裁措施和影响尚不明确，市场可能需要时间消化。
# 3.  **市场对“不确定性”的厌恶：** 特朗普政府的政策具有高度不确定性，市场通常不喜欢这种不确定性。当一个明确的负面威胁（50%关税）被推迟时，即便是暂时的，市场也会做出积极回应。
# 4.  **节假日效应：** 阵亡将士纪念日后的第一个交易周，市场在经历周末假期后通常会根据最新的重大消息进行调整。在没有新的重大利空出现的情况下，关税推迟的消息将成为主导情绪。
# 5.  **行业的具体影响：** 关税的推迟直接缓解了贸易相关企业的压力，而其他政策的影响则相对分散或需要更长时间显现。因此，总体上市场情绪应偏向乐观。
#
# 然而，需要注意的是，特朗普政策的反复性意味着其立场可能再次改变，投资者仍需保持警惕。

# %%
import sqlite3

# 数据库文件路径
DB_FILE = 'mydatabase.db'

def connect_db():
    """连接到 SQLite 数据库并返回连接对象和游标对象"""
    try:
        conn = sqlite3.connect(DB_FILE)
        # 设置 row_factory 可以让查询结果以字典形式返回，更方便访问
        conn.row_factory = sqlite3.Row
        cursor = conn.cursor()
        print(f"成功连接到数据库: {DB_FILE}")
        return conn, cursor
    except sqlite3.Error as e:
        print(f"连接数据库失败: {e}")
        return None, None

def close_db(conn):
    """关闭数据库连接"""
    if conn:
        conn.close()
        print("数据库连接已关闭。")

# --- 增 (INSERT) ---
def add_user(name, age):
    conn, cursor = connect_db()
    if conn and cursor:
        try:
            sql = "INSERT INTO users (name, age) VALUES (?, ?)"
            cursor.execute(sql, (name, age))
            conn.commit()  # 提交事务，保存更改
            print(f"用户 '{name}' (年龄: {age}) 已成功添加，新ID: {cursor.lastrowid}")
        except sqlite3.Error as e:
            print(f"添加用户失败: {e}")
        finally:
            close_db(conn)

# --- 查 (SELECT) ---
def get_all_users():
    conn, cursor = connect_db()
    users = []
    if conn and cursor:
        try:
            cursor.execute("SELECT id, name, age FROM users")
            rows = cursor.fetchall()  # 获取所有结果
            print("\n--- 所有用户 ---")
            for row in rows:
                # row 可以像字典一样访问，因为设置了 row_factory
                print(f"ID: {row['id']}, 姓名: {row['name']}, 年龄: {row['age']}")
                users.append(dict(row)) # 如果需要返回字典列表
        except sqlite3.Error as e:
            print(f"查询所有用户失败: {e}")
        finally:
            close_db(conn)
    return users

def get_user_by_id(user_id):
    conn, cursor = connect_db()
    user = None
    if conn and cursor:
        try:
            sql = "SELECT id, name, age FROM users WHERE id = ?"
            cursor.execute(sql, (user_id,)) # 注意元组即使只有一个元素也要加逗号
            user_data = cursor.fetchone() # 获取单个结果
            if user_data:
                user = dict(user_data)
                print(f"\n--- 查询ID为 {user_id} 的用户 ---")
                print(f"ID: {user['id']}, 姓名: {user['name']}, 年龄: {user['age']}")
            else:
                print(f"\n未找到ID为 {user_id} 的用户。")
        except sqlite3.Error as e:
            print(f"按ID查询用户失败: {e}")
        finally:
            close_db(conn)
    return user

# --- 改 (UPDATE) ---
def update_user_age(user_id, new_age):
    conn, cursor = connect_db()
    if conn and cursor:
        try:
            sql = "UPDATE users SET age = ? WHERE id = ?"
            cursor.execute(sql, (new_age, user_id))
            conn.commit()
            if cursor.rowcount > 0: # 检查是否有行受到影响
                print(f"\n成功更新用户ID {user_id} 的年龄为 {new_age}。")
            else:
                print(f"\n未找到ID为 {user_id} 的用户，或年龄未改变。")
        except sqlite3.Error as e:
            print(f"更新用户失败: {e}")
        finally:
            close_db(conn)

# --- 删 (DELETE) ---
def delete_user(user_id):
    conn, cursor = connect_db()
    if conn and cursor:
        try:
            sql = "DELETE FROM users WHERE id = ?"
            cursor.execute(sql, (user_id,))
            conn.commit()
            if cursor.rowcount > 0:
                print(f"\n成功删除用户ID {user_id}。")
            else:
                print(f"\n未找到ID为 {user_id} 的用户。")
        except sqlite3.Error as e:
            print(f"删除用户失败: {e}")
        finally:
            close_db(conn)

# --- 主执行流程 ---
if __name__ == "__main__":
    # 确保数据库文件存在并有 users 表
    # 如果文件不存在，会自动创建；如果表不存在，也会创建
    conn, cursor = connect_db()
    if conn and cursor:
        try:
            cursor.execute('''
                CREATE TABLE IF NOT EXISTS users (
                    id INTEGER PRIMARY KEY AUTOINCREMENT,
                    name TEXT NOT NULL,
                    age INTEGER
                )
            ''')
            conn.commit()
            print("确保 'users' 表已存在。")
        except sqlite3.Error as e:
            print(f"创建/检查表失败: {e}")
        finally:
            close_db(conn)

    print("\n--- 执行操作示例 ---")

    # 1. 增 (INSERT)
    add_user("王五", 28)
    add_user("赵六", 35)

    # 2. 查 (SELECT) - 查询所有用户
    get_all_users()

    # 3. 查 (SELECT) - 按ID查询特定用户 (假设王五的ID是3，赵六的ID是4，因为张三李四是1,2)
    # 实际ID可能需要根据你的数据库状态来确定
    # 我们可以尝试查询最新添加的用户ID
    temp_conn, temp_cursor = connect_db()
    if temp_conn and temp_cursor:
        temp_cursor.execute("SELECT id FROM users ORDER BY id DESC LIMIT 1")
        last_id = temp_cursor.fetchone()['id']
        close_db(temp_conn)
        get_user_by_id(last_id) # 假设这就是刚添加的赵六

    # 4. 改 (UPDATE)
    update_user_age(last_id, 36) # 将赵六的年龄改为36

    # 再次查询，确认修改
    get_all_users()

    # 5. 删 (DELETE)
    # 假设我们要删除之前添加的王五，我们需要知道他的ID。
    # 简单起见，我们这里直接删除 ID 为 3 的用户 (如果王五是第三个添加的)
    # 在实际应用中，你可能需要先查询ID
    delete_user(last_id - 1) # 假设王五的ID是赵六ID的前一个

    # 再次查询，确认删除
    get_all_users()

    print("\n所有操作完成。")

# %% [markdown]
# # 根据YouTube链接分析

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model='models/gemini-2.5-flash-preview-05-20',
    contents=types.Content(
        parts=[
            types.Part(
                file_data=types.FileData(file_uri='https://www.youtube.com/watch?v=y9bE1CZ2dfU')
            ),
            types.Part(text="""
作为一名专业的美股分析师，请深度分析这个视频内容，重点关注以下方面：

## 分析要求：
1. **新闻事件提取**：提取视频中作者提到的每一条客观的新闻事件,并识别每条新闻事件的发生日期
2. **作者观点提取**：识别并列出作者对每一条新闻事件的所有重要观点和结论
3. **涉及美股提取**：重点分析作者每个观点中提到的美股股票，使用标准的美股股票代码，标普500使用SPY,nasdaq使用QQQ，如果作者没有提及具体股票，则填"none"，如果涉及大盘整体则填"all"
4. **股票趋势预测**：根据作者观点，预测每个股票的未来趋势，分为5类：超级看涨、看涨、中立、看跌、超级看跌
5. **影响范围**：分析每个事件和股票的影响时间范围，分为未来1～3天、未来一周、未来一个月及以上
6. **输出格式**：输出一个Json格式的列表，以新闻事件和涉及股票的组合构造每个元素，如果一条新闻事件提到了多个股票，则要拆分为多个元素，每个元素包含视频链接、博主名字、视频日期、新闻事件描述、事件日期、作者观点、股票代码、预测趋势和影响时间范围这9个字段


## 输出格式具体要求：
请严格按照以下Json格式输出分析结果，对于视频中提到的每一个事件和股票标的的组合，输出一个包含以下必填字段的字典：

{
    "results": 
        [
        {
            "video_url": "视频链接",
            "blogger_name": "博主名字",
            "video_date": "视频发布日期",
            "news_event": "新闻事件的客观描述",
            "news_event_date": "新闻事件发生的日期",
            "author_opinion": "作者对该事件和股票的具体观点",
            "stock_symbol": "作者提到的美股标准的股票代码，标普500使用SPY,nasdaq使用QQQ，如果作者没有提及则填"none",对美股全部大盘用"all"",
            "author_prediction": "5类股票趋势的预测：超级看涨、看涨、中立、看跌、超级看跌",
            "impact_timeframe": "3类影响范围：未来1～3天、未来一周、未来一个月及以上",
        },
            {
                "video_url": "视频链接",
                "blogger_name": "博主名字",
                "video_date": "视频发布日期",
                "news_event": "另一条新闻事件的客观描述",
                "news_event_date": "新闻事件发生的日期",
                "author_opinion": "作者对该事件和股票的具体观点",
                "stock_symbol": "作者提到的美股标准的股票代码，标普500使用SPY,nasdaq使用QQQ，如果作者没有提及则填"none",对美股全部大盘用"all"",
                "author_prediction": "5类股票趋势的预测：超级看涨、看涨、中立、看跌、超级看跌",
                "impact_timeframe": "3类影响范围：未来1～3天、未来一周、未来一个月及以上"
            },
            # 更多事件和股票的组合...
        ]
}
"""
            )
        ]
    )
)
for each in response.candidates[0].content.parts:
    print(each.text)
# Out:
# ```json
# {
#     "results": [
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "美国股市、美元、美债在长周末后强势反弹，黄金大跌，标普500指数和纳斯达克指数收涨超2%，道琼斯指数收涨1.78%。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "市场乐观情绪重新抬头，绝大多数股票都跟随大盘上涨，除了黄金以外，其他热门板块也都普涨。",
#             "stock_symbol": "all",
#             "author_prediction": "超级看涨",
#             "impact_timeframe": "未来1～3天"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "特朗普在周末表示，推迟对欧盟加征50%关税的计划，恢复了7月9日的最后期限。",
#             "news_event_date": "2024-05-25",
#             "author_opinion": "这提振了市场乐观情绪。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一周"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "白宫经济委员会主任哈塞特表示，部分国家的关税可能降到10%或更低，并且预计本周会达成多份贸易协议。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "这些消息提振了市场，预示着贸易紧张局势的缓和。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一周"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "日本和美国债市都出现了缓解，日本超长期国债收益率应声回落，美国30年期美债收益率降到5%以下。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "这推动了全球股市的反弹。当政策制定者开始恐慌的时候，股市就不再恐慌了，因为政策制定者恐慌的时候就会推出各种宽松措施来安抚市场。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一周"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "美国财政部今天690亿美元的两年期美债拍卖结果很成功，需求稳定也帮助稳定了债市。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "需求水平可能会影响美债、美股和美元的走势。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来1～3天"
#         },
#         {
#             "video_url": "https://www.youtube.com": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "美国消费者信心在经历了五个月的低迷之后出现反弹，5月数据从前月的85.7上升到98，高于所有经济学家预期，预测范围在82到91.8。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "消费者信心回升不仅体现在对当前经济状况的评估上，也体现在对未来的预期方面。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一个月及以上"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "通胀预期中值从上个月的5.9%回落到5.3%。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "此次信心回升主要得益于5月初以来公布的一系列强劲的经济数据，以及第一季度企业财报都好于市场预期。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一个月及以上"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "在5月12日中美达成临时协议之前，消费者信心就已经有所改善了。在协议达成之后，信心增长的速度加快，进一步加强了消费者对经济状况的乐观情绪。",
#             "news_event_date": "2024-05-12",
#             "author_opinion": "整体市场情绪乐观，支持大盘上涨。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一个月及以上"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "随着5月美国股市的持续复苏，消费者对股市未来走势的预期也随之转好，44%的消费者预计未来12个月美国股市将会继续上涨，明显高于4月时的37.7%。而预计市场将下跌的比例从47.2%下降到37.7%。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "这种强劲表态可能表明第四浪小回调已经结束，第五浪上涨行情大概率已经正式启动了。没人敢做空，即使是最悲观的交易员也只能先保持观望。机构还有很大的空间可以继续加仓风险资产。",
#             "stock_symbol": "all",
#             "author_prediction": "超级看涨",
#             "impact_timeframe": "未来一个月及以上"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "标普500指数今天跳空高开，收盘成功站上了5日、10日均线。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "如果接下来一两天不再跌破这两条均线的话，那就意味着第五浪上涨行情大概率就以及正式启动了。这种时候，想要阻挡做多大军，就有如一个人张开双臂，想要阻拦一列狂奔而来的火车一样悲壮。今天的股指全天一路飙升，估计就是市场开始抢跑了，起码有一部分逢低买入的资金一拥而上，生怕错过接下来这一波主升段。 第五浪行情虽然涨得猛，但它通常出现在市场上行周期的尾声阶段，往往会伴随着疯狂的涨幅，涨幅幅度很难预测，有时候比第三浪小，有时候甚至更大，整个过程市场情绪会异常的亢奋。 但是一旦行情结束就可能迎来剧烈且迅猛的反转，也就是那个经典的ABC三段式下跌，把前面涨的全部吐出去，前面涨的有多凶，后面跌的就有多猛。所以第五浪也被称为邪恶的第五浪，它往往会做空头死的很惨，很多人不信邪，硬要逆势做空，最后就被无情的嘎爆。 而很多普通投资者在这个时候就情绪上头买在最高点，结果被深度套牢。所以要是想在第五浪行情中赚大钱，必须要注意两点：一是千万别逆势做空，不要成为人家上涨的燃料；二就是不要盲目的乐观，始终要保持风控意识。当第五浪连涨多日，涨幅偏大之后就不要再继续去追高了，要开始逐步的落袋为安。行情总会拐弯的，一旦趋势反转，我们得确保自己能够全身而退。还有一点需要特别留意，虽然大盘在第五浪上升行情中可能会创下历史新高，但并不是所有股票都会跟着普涨，因为前面的第一浪和第三浪呢已经消耗了大量的买盘动能，等到第五浪的时候市场靠的更多是惯性在拉升，新资金进场的力度会减弱，而更关键的是这个阶段通常是由散户情绪主导，很多机构主力者会趁机在高位分批出货。呈现出来的结果就是大盘指数在此期间会被权重股或者少数龙头不断的推高，但是大量的个股开始走弱，市场广度会明显的变差，反映出趋势末期的虚假繁荣。",
#             "stock_symbol": "SPY",
#             "author_prediction": "超级看涨",
#             "impact_timeframe": "未来一个月及以上"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "波动率指数VIX今天大跌，因英伟达财报公布之前市场情绪已经全面转多。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "交易员们对于买入保护性看跌期权完全不感兴趣，似乎完全不担忧明天英伟达财报会暴雷或怎样的。目前场外还有大约7万亿美金的现金在观望。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来1～3天"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "机构在股市的整体持仓仍未达到狂热的水平，CTA目前对股市的整体敞口是中性状态，而对冲基金和共同基金依然大幅低配科技股。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "换句话说，机构们还有很大的空间可以继续加仓风险资产。如果明天盘后英伟达能交出一份乐观的财报，那市场就有可能被彻底点燃，引发新一轮的FOMO情绪，而这正是推动第五浪行情的基础。",
#             "stock_symbol": "all",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一个月及以上"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "英伟达将为中国市场推出一款低阶AI芯片，售价介于6500美元到8000美元之间，远低于先前的阉割版H20芯片，预计最快6月开始量产，性能要低很多，价格当然也要低很多。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "公司明天盘后就公布财报了，投资者也期待了解美国政府对中国的芯片限制将会给公司带来多少的损失。美银预计英伟达第一季度业绩还是会小幅超出市场预期，但是鉴于政策限制，对第二季度的前瞻指引可能会存在的一些不确定性。但是这些预测其实都不重要了，作为美股AI热潮的风向标，若是大盘真的确定要启动第五浪上升行情的话，那英伟达的股价就必须上涨，即时不涨也得横着，总之就不能够大跌。如果大跌把大盘也给带崩了，那就说明今天这个市场的大涨就只是第四浪的反抽而已，回落仍未结束。所以明天我们还可以再观望一下。",
#             "stock_symbol": "NVDA",
#             "author_prediction": "中立",
#             "impact_timeframe": "未来1～3天"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "拼多多盘中一度跌超18%，尾盘跌幅收窄到13.6%。公司盘前公布的第一季度盈利和营收都远低于市场预期，Q1营收同比增长了10%，达到95亿元人民币，不及市场预期的103亿元。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "这个业绩表现，那股价跌这么多一点都不冤枉是吧。中概股自4月初以来这一轮上涨行情完全是脱离基本面的，就无视了关税因素还有国内经济通缩的基本面。拼多多也基本无视了它的国际业务Temu受到全球贸易政策不确定性冲击。",
#             "stock_symbol": "PDD",
#             "author_prediction": "看跌",
#             "impact_timeframe": "未来一周"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "拼多多净利润147亿元，同比下滑了47%，几乎腰斩，主要是因为营销费用激增了43%拖累了整体盈利。美股收益11.4元人民币，也大幅不及预期的19.4元。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "所以中概股这种市场有点不太放心，巴菲特那一套所谓的价值投资，买入之后几年几十年不放，这个在中概股上面是完全不合适的，虽然拼多多也属于中概股龙头企业之一了，不是什么妖股或者是一些小盘股，但是我们在美股里面也只能够当做题材概念股或投机股来炒。",
#             "stock_symbol": "PDD",
#             "author_prediction": "看跌",
#             "impact_timeframe": "未来一个月及以上"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "苹果股价反弹了2.53%，数据显示公司4月份从印度出货的iPhone达到了约300万部，同比增长了76%。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "如果接下来大盘不崩，特朗普不喷，那么苹果的股价或许还是能够继续反弹的。",
#             "stock_symbol": "AAPL",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一周"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "摩根士丹利分析师表示，即使特朗普威胁对进口美国的iPhone征收25%关税，海外生产成本仍然更具优势，不足以促使苹果将生产线迁回到美国，他们算了一下，如果要在美国建立iPhone组装厂，至少得耗时两年，投入数十亿美元，而且在美国造iPhone成本比在中国或者印度贵了整整35%。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "相比之下，即使关税涨25%，苹果也只需要涨4%到6%的售价就能够抵消这笔额外成本了，根本就不值得大动干戈嘛。如果苹果坚决不迁回美国，那与特朗普政府的关系也可能因此恶化，未来或许会面临更高的关税风险。特朗普说不定会威胁征收50%的关税呢。分析师认为呢，苹果就可能需要通过增加美国投资来缓解压力，给大统领一些面子，作为他承诺5000亿美元投资计划的一部分。",
#             "stock_symbol": "AAPL",
#             "author_prediction": "中立",
#             "impact_timeframe": "未来一个月及以上"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "DJT股价今天盘前还一度涨超16%，但盘中高开低走，收跌10.4%。昨天还是今天盘前，英国金融时报称公司打算学MSTR，计划于5月29号前后发行大约15亿美元的股票和10亿美元的可转换债券，筹集约25亿美元资金用于购买比特币等一些加密货币。报告还补充称公司已经与约50家机构投资者签订了认购协议。盘前的时候公司还回应称英国金融时报胡说，这是假新闻，结果盘中就宣布了增发的公告。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "很多时候所谓的谣言，最后被证明只不过是在错误的时间，有错误的人发布了一个真的消息。这个股票嘛，就是个可待都知道，没什么基本面好分析的是吧，反正就瞎炒呗，赌徒们去拉斯维加斯赌博，你还得开车跑大老远，又费时间又费油钱，这炒股票多好，在家里打开电脑就可以赌大小了。公司手里目前还有现金，截至第一季度末，公司持有现金、现金等价物，一共7.59亿美元，所以这个短期也没有破产风险，就跟赌大小没区别。",
#             "stock_symbol": "DJT",
#             "author_prediction": "中立",
#             "impact_timeframe": "未来一周"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "AMC股价涨了近24%，在刚刚过去的超长周末，电影院客流量回升，美国的AMC影院票房收入创下了新的历史记录，增强投资者对电影院线业务复苏的信心。这个强劲表现主要是得益于当下有多部大片首映，包括迪士尼的真人版星际宝贝，还有Tom Cruise最新一部谍中谍系列电影。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "股价虽然从近期低点已经反弹了超过50%了，今天日K高点就触及到了250日均线。若是能够成功突破并且站稳，就能够成功扭转中期趋势了。若是接下来出现回调呢也不需要太担心，下方半年线这里会是个短期支撑，可能回调不到这里就会再反弹上去了。",
#             "stock_symbol": "AMC",
#             "author_prediction": "看涨",
#             "impact_timeframe": "未来一周"
#         },
#         {
#             "video_url": "https://www.youtube.com/watch?v=1F3gG0LgT10",
#             "blogger_name": "NaNa说美股",
#             "video_date": "2024-05-27",
#             "news_event": "UNH这种防御性的股票在市场当下看多情绪高涨的时候，表现往往都不会太好。当市场动荡，避险情绪升温，才是这种防御性股票表演的时候。",
#             "news_event_date": "2024-05-27",
#             "author_opinion": "所以现在手里有这只股票的，现阶段就只能够保持耐心将该股作为长线仓位持有，或者作为另一个防御性板块来持有了。",
#             "stock_symbol": "UNH",
#             "author_prediction": "中立",
#             "impact_timeframe": "未来一个月及以上"
#         }
#     ]
# }
# ```

# %% [markdown]
# # 获取博主YouTube视频链接

# %%
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'
CHANNEL_NAME_TO_SEARCH = '@NaNaShuoMeiGu'

def get_youtube_service():
    """构建并返回 YouTube 服务对象，API 密钥从环境变量读取。"""
    api_key = os.environ.get('GOOGLE_API_KEY')
    if not api_key:
        print("错误：请设置 GOOGLE_API_KEY 环境变量。")
        return None
    try:
        youtube = build(YOUTUBE_API_SERVICE_NAME,
                        YOUTUBE_API_VERSION,
                        developerKey=api_key)
        return youtube
    except Exception as e:
        print(f"构建 YouTube 服务时出错: {e}")
        return None

def find_channel_id(youtube_service, channel_name):
    """根据频道名称搜索并返回频道 ID。"""
    if not youtube_service:
        return None
    try:
        search_response = youtube_service.search().list(
            q=channel_name,
            part='snippet',
            type='channel',
            maxResults=1
        ).execute()

        if not search_response.get('items'):
            print(f"未能找到名为 '{channel_name}' 的频道。")
            return None
        
        channel_id = search_response['items'][0]['snippet']['channelId']
        found_channel_title = search_response['items'][0]['snippet']['title']
        print(f"找到频道: '{found_channel_title}' (ID: {channel_id})")
        return channel_id
    except HttpError as e:
        print(f"搜索频道 ID 时发生 HTTP 错误 {e.resp.status}: {e.content}")
        return None
    except Exception as e:
        print(f"搜索频道 ID 时发生错误: {e}")
        return None

def get_latest_uploaded_video_link(youtube_service, channel_id_value):
    """获取指定频道 ID 的最新上传视频链接 (非直播回放)。"""
    if not youtube_service or not channel_id_value:
        return None
    
    # 从频道 ID 推断上传播放列表 ID
    # 例如，如果频道 ID 是 UCxxxxxxxxxxxxxxx，上传播放列表 ID 就是 UUxxxxxxxxxxxxxxx
    if not channel_id_value.startswith('UC'):
        print(f"错误：频道 ID '{channel_id_value}' 格式不正确，它应该以 'UC' 开头。")
        return None
    uploads_playlist_id = 'UU' + channel_id_value[2:]

    try:
        # 使用 playlistItems().list 获取上传播放列表的视频
        playlist_items_response = youtube_service.playlistItems().list(
            part='snippet,contentDetails', # 我们需要 contentDetails 来获取 videoId
            playlistId=uploads_playlist_id,
            maxResults=1 # 获取最新的一个
            # 对于上传播放列表，视频默认就是按添加时间倒序排列的
        ).execute()

        if not playlist_items_response.get('items'):
            print(f"频道 {channel_id_value} (上传播放列表 {uploads_playlist_id}) 中没有找到视频。")
            return None

        # 从播放列表项中获取视频 ID 和标题
        latest_video_item = playlist_items_response['items'][0]
        video_id = latest_video_item['contentDetails']['videoId']
        video_title = latest_video_item['snippet']['title']
        
        # 构建标准的 YouTube 视频链接
        video_url = f'https://www.youtube.com/watch?v={video_id}'
        
        print(f"最新上传视频标题: {video_title}")
        return video_url
    except HttpError as e:
        print(f"获取最新上传视频时发生 HTTP 错误 {e.resp.status}: {e.content}")
        return None
    except Exception as e:
        print(f"获取最新上传视频时发生错误: {e}")
        return None

if __name__ == '__main__':
    youtube = get_youtube_service()
    if youtube:
        channel_id = find_channel_id(youtube, CHANNEL_NAME_TO_SEARCH)
        if channel_id:
            # 调用新的函数
            latest_video_url = get_latest_uploaded_video_link(youtube, channel_id)
            if latest_video_url:
                print(f"\n{CHANNEL_NAME_TO_SEARCH} 的最新上传视频链接是: {latest_video_url}")
            else:
                print("未能获取到最新上传视频链接。")
        else:
            print(f"未能找到频道 '{CHANNEL_NAME_TO_SEARCH}'。")
# Out:
# 找到频道: 'NaNa说美股' (ID: UCFhJ8ZFg9W4kLwFTBBNIjOw)
# 最新上传视频标题: 今天纯粹耍猴戏！NaNa说美股(2025.05.29)
#
# @NaNaShuoMeiGu 的最新上传视频链接是: https://www.youtube.com/watch?v=7QvLC0bg-Z8

# %%
import os
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google import genai # 完全按照您提供的导入
from google.genai import types # 完全按照您提供的导入

# --- YouTube API 相关配置 ---
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'
CHANNEL_NAME_TO_SEARCH = 'NaNa说美股' # 来自您的第一个脚本

# --- Gemini API 相关配置 ---
# GEMINI_MODEL_NAME = 'models/gemini-2.5-flash-preview-04-17' # 模型名称直接在调用时使用

def get_youtube_service():
    """构建并返回 YouTube 服务对象，API 密钥从环境变量读取。"""
    api_key = os.environ.get('GOOGLE_API_KEY')
    if not api_key:
        print("错误：请设置 GOOGLE_API_KEY 环境变量。")
        return None
    try:
        # 注意: Gemini 的初始化 (如 genai.configure) 如果需要，应在此处或调用前处理
        # 但根据您的要求，不修改除融合之外的逻辑
        youtube = build(YOUTUBE_API_SERVICE_NAME,
                        YOUTUBE_API_VERSION,
                        developerKey=api_key)
        return youtube
    except Exception as e:
        print(f"构建 YouTube 服务时出错: {e}")
        return None

def find_channel_id(youtube_service, channel_name):
    """根据频道名称搜索并返回频道 ID。"""
    if not youtube_service:
        return None
    try:
        search_response = youtube_service.search().list(
            q=channel_name,
            part='snippet',
            type='channel',
            maxResults=1
        ).execute()

        if not search_response.get('items'):
            print(f"未能找到名为 '{channel_name}' 的频道。")
            return None
        
        channel_id = search_response['items'][0]['snippet']['channelId']
        found_channel_title = search_response['items'][0]['snippet']['title']
        print(f"找到频道: '{found_channel_title}' (ID: {channel_id})")
        return channel_id
    except HttpError as e:
        print(f"搜索频道 ID 时发生 HTTP 错误 {e.resp.status}: {e.content}")
        return None
    except Exception as e:
        print(f"搜索频道 ID 时发生错误: {e}")
        return None

def get_latest_uploaded_video_link(youtube_service, channel_id_value):
    """获取指定频道 ID 的最新上传视频链接 (非直播回放)。"""
    if not youtube_service or not channel_id_value:
        return None, None
    
    if not channel_id_value.startswith('UC'):
        print(f"错误：频道 ID '{channel_id_value}' 格式不正确，它应该以 'UC' 开头。")
        return None, None
    uploads_playlist_id = 'UU' + channel_id_value[2:]

    try:
        playlist_items_response = youtube_service.playlistItems().list(
            part='snippet,contentDetails', 
            playlistId=uploads_playlist_id,
            maxResults=1
        ).execute()

        if not playlist_items_response.get('items'):
            print(f"频道 {channel_id_value} (上传播放列表 {uploads_playlist_id}) 中没有找到视频。")
            return None, None

        latest_video_item = playlist_items_response['items'][0]
        video_id = latest_video_item['contentDetails']['videoId']
        video_title = latest_video_item['snippet']['title']
        video_url = f'https://www.youtube.com/watch?v={video_id}' # 您脚本中的链接格式
        
        print(f"获取到最新上传视频: '{video_title}'")
        print(f"视频链接: {video_url}")
        return video_url, video_title
    except HttpError as e:
        print(f"获取最新上传视频时发生 HTTP 错误 {e.resp.status}: {e.content}")
        return None, None
    except Exception as e:
        print(f"获取最新上传视频时发生错误: {e}")
        return None, None

if __name__ == '__main__':
    youtube_service = get_youtube_service()
    
    if youtube_service:
        channel_id = find_channel_id(youtube_service, CHANNEL_NAME_TO_SEARCH)
        if channel_id:
            latest_video_url, latest_video_title = get_latest_uploaded_video_link(youtube_service, channel_id)
            
            if latest_video_url and latest_video_title:
                print(f"\n准备使用 Gemini 分析视频: '{latest_video_title}'")
                
                # --- 开始使用您第二份脚本中的 Gemini 调用逻辑 ---
                try:
                    # 确保 GOOGLE_API_KEY 环境变量已设置，Gemini 通常会自动使用
                    # 如果 genai.configure() 需要被调用，用户需要确保它在 genai.Client() 之前被正确处理
                    # 此处严格按照用户提供的片段进行融合
                    client = genai.Client() # 完全按照您提供的代码

                    # 您提供的 Gemini 提示文本
                    gemini_prompt_text = (
                        '请总结这个视频，并分条列出视频中作者的所有观点和结论。'
                        '重点每条新闻解读对于美股的分析和判断，给出关于利好或者利空的观点总结。'
                        '最后，给出一个json格式的总结，包含以下字段：\n'
                        '1. 公司/行业\n'
                        '2. 新闻及观点的简短总结\n'
                        '3. 结论（利好/利空）\n'
                        '4. 置信度（0-1之间的浮点数）\n'
                        '5. 分析逻辑'
                    )
                    
                    # 使用从 YouTube 获取的 latest_video_url
                    # 注意：您第二份代码中的 file_uri 是 'https://www.youtube.com/watch?v=AF3u0wt_RS8'，这里替换为实际获取的链接
                    video_part = types.Part(
                        file_data=types.FileData(file_uri=latest_video_url)
                    )
                    prompt_part = types.Part(text=gemini_prompt_text)

                    print(f"向 Gemini 发送请求，视频 URI: {latest_video_url}")
                    
                    # 完全按照您提供的代码结构调用
                    response = client.models.generate_content(
                        model='models/gemini-2.5-flash-preview-04-17', # 您指定的模型
                        contents=types.Content(parts=[video_part, prompt_part]) # types.Content 构造
                    )
                    
                    print("\nGemini 回复内容:")
                    for each in response.candidates[0].content.parts:
                        print(each.text)

                except Exception as e:
                    print(f"调用 Gemini API 时发生错误: {e}")
                    print("请确保您的 GOOGLE_API_KEY 已正确设置，并且具有访问 Gemini API 的权限。")
                    print("同时，请确认您环境中的 'google-generativeai' 库版本与您提供的 Gemini 调用代码兼容。")
                # --- Gemini 调用逻辑结束 ---
            else:
                print("未能获取到最新视频链接，无法进行总结。")
        else:
            print(f"未能找到频道 '{CHANNEL_NAME_TO_SEARCH}'，无法继续。")
    else:
        print("未能初始化 YouTube 服务，脚本终止。")
# Out:
# 找到频道: 'NaNa说美股' (ID: UCFhJ8ZFg9W4kLwFTBBNIjOw)
# 获取到最新上传视频: '这次不怕了？NaNa说美股(2025.05.22)'
# 视频链接: https://www.youtube.com/watch?v=Gpd0KEhclyY
#
# 准备使用 Gemini 分析视频: '这次不怕了？NaNa说美股(2025.05.22)'
# 向 Gemini 发送请求，视频 URI: https://www.youtube.com/watch?v=Gpd0KEhclyY
#
# Gemini 回复内容:
# 好的，这是视频内容的总结以及分条列出的作者观点和结论：
#
# **视频总结：**
#
# 视频首先回顾了昨日美股下跌后，投资者逢低买入大型科技股，使得今天大盘基本持稳。然而，对美国高债务水平的持续担忧使得市场情绪脆弱。经济数据方面，美国上周初请失业金人数意外下降，5月制造业和服務业PMI初值均超出市场预期，表明劳动力市场健康，经济持续增长。这些数据为美联储推迟降息提供了理由，市场认为6月降息的概率降低。
#
# 新闻方面，特朗普的税改法案在共和党主导的众议院以微弱优势通过，但可能会增加国家债务。日本国债收益率的飙升成为美股面临的主要风险，可能引发资本流出美国资产。
#
# 个股和板块方面，受到税改法案相关新闻影响，前几天大幅上涨的太阳能股票（如Sunrun）今天却暴跌，作者认为之前的上涨是基于对政策的误读，是庄家拉高出货。Deckers Outdoor (DECK) 财报后因展望不及预期和关税担忧大跌。Snowflake (SNOW) 财报超出预期并提高了全年指引，股价大涨，但作者提示其估值过高且存在股权稀释问题。美国加密货币交易所Kraken计划推出热门美股的代币化版本，允许非美国客户24/7交易，可能增加美股流动性。房地美 (FMCC) 和房利美 (FNMA) 因特朗普考虑让它们重新上市的言论而大涨。耐克 (NKE) 宣布提高产品价格，可能与关税影响有关，同时宣布回归亚马逊平台并扩张线下零售。联合健康 (UNH) 受媒体爆料和政府扩大医保审计范围的消息影响，连续回落。
#
# **作者观点和结论总结：**
#
# 1.  **整体美股市场:**
#     *   **新闻/观点:** 在前一天下跌后，得益于投资者买入大科技股，大盘今天企稳。但因对美国高债务的持续担忧，市场情绪脆弱，维持窄幅震荡。
#     *   **结论:** 中性 (偏谨慎)
#     *   **置信度:** 0.7
#     *   **分析逻辑:** 数据面好于预期，但债务担忧挥之不去，且市场已对降息预期降温，多空因素交织导致市场盘整。
#
# 2.  **美国经济数据 (初请失业金人数, PMI):**
#     *   **新闻/观点:** 初请失业金人数降至四周最低，5月制造业/服务业PMI均超预期并处于扩张区间。
#     *   **结论:** 利好经济，利空降息预期
#     *   **置信度:** 0.9
#     *   **分析逻辑:** 强劲的就业和PMI数据表明经济健康，给了美联储推迟降息的底气。
#
# 3.  **美联储降息预期:**
#     *   **新闻/观点:** 强劲的经济数据支持美联储推迟降息。
#     *   **结论:** 利空降息（6月降息概率低）
#     *   **置信度:** 0.8
#     *   **分析逻辑:** 经济表现良好减少了美联储紧急降息的必要性。
#
# 4.  **特朗普税改法案 (众议院通过):**
#     *   **新闻/观点:** 众议院通过特朗普税改法案，延长减税、削减社保/医保支出、增加国防/边境安全开支，预计未来10年增债3.8-5万亿。
#     *   **结论:** 混合 (政策内容复杂，对市场情绪有影响，对债务是利空)
#     *   **置信度:** 0.7 (对政策内容和通过情况的描述是事实，但对未来影响是基于分析)
#     *   **分析逻辑:** 政策本身包含减税（潜在利好增长/股市）和增支/增债（利空财政健康/长期）。作者特别提及了共和党内部分歧及特朗普的施压，并引用了“忠诚不绝对，就是绝对不忠诚”的说法，暗示政治因素对政策的影响。对国家债务的增加是明确的利空。
#
# 5.  **美国国债收益率:**
#     *   **新闻/观点:** 受税改法案通过消息刺激一度冲高，但随后回落，出现大量买盘。
#     *   **结论:** 暂时利好美债价格/利空收益率（疑似干预），但长期风险存在
#     *   **置信度:** 0.7
#     *   **分析逻辑:** 作者怀疑是财政部或美联储指挥金融机构买入债券以压低收益率、稳定债市，以应对日本国债收益率飙升带来的全球资产流动风险。
#
# 6.  **日本国债收益率飙升:**
#     *   **新闻/观点:** 日本30年/40年国债收益率创25年新高。
#     *   **结论:** 全球市场主要风险（利空美股/美债/美元）
#     *   **置信度:** 0.9
#     *   **分析逻辑:** 日本国债收益率上升可能导致资本从美国资产流出，去平仓日元套利交易，对全球资产流动性产生巨大吸力，冲击美股、美债和美元。作者认为这是比美国财政政策更重要的影响因素。
#
# 7.  **太阳能板块 (RUN, TAN):**
#     *   **新闻/观点:** 前期因税改法案（不完全取消抵免）预期大幅上涨，法案众议院通过后却暴跌，回吐涨幅。法案中包含结束电动汽车税收抵免等，且作者认为之前是媒体误读了政策。
#     *   **结论:** 强烈利空 (前期上涨是“骗傻子的”，拉高出货)
#     *   **置信度:** 0.9
#     *   **分析逻辑:** 作者认为税改法案并未完全利好，之前的上涨是庄家利用市场情绪进行的炒作和出货，并直言只有民主党执政才能看好绿色能源股。
#
# 8.  **Deckers Outdoor (DECK):**
#     *   **新闻/观点:** 财报显示营收和利润超预期，但本季度展望不及预期，且因关税担忧未提供全年指引，盘后大跌。
#     *   **结论:** 强烈利空
#     *   **置信度:** 0.9
#     *   **分析逻辑:** 展望不及预期和缺乏全年指引通常是市场担忧的信号，尤其是在外部环境不确定（如关税）的情况下，公司基本面受压。
#
# 9.  **Snowflake (SNOW):**
#     *   **新闻/观点:** 财报超预期，产品营收和RPO增长稳健，并上调全年指引。积极招聘销售人员。股价大涨。
#     *   **结论:** 混合 (短期利好，但作者强调长期风险/高估值)
#     *   **置信度:** 0.7 (作者承认业绩数据不错，但对股票本身持谨慎态度)
#     *   **分析逻辑:** 业绩和指引超出预期是短期利好，推动股价上涨。但作者强调其超高估值（远高于同业），高股权稀释成本，以及至今未盈利的基本面问题，认为其是“庄股”，不适合追高或抄底，只能顺势操作。
#
# 10. **加密货币/Tokenized Equities (Kraken):**
#     *   **新闻/观点:** 比特币创历史新高。Kraken交易所计划推出美股和ETF的代币化版本，允许非美国客户24/7交易。
#     *   **结论:** 潜在利好 (增加美股流动性/全球可及性)
#     *   **置信度:** 0.6 (作者提到类似尝试曾因监管暂停，对此计划能否最终落实存疑)
#     *   **分析逻辑:** 代币化美股理论上能降低海外投资者交易门槛，增加市场整体流动性和参与度。但监管的不确定性是潜在障碍。
#
# 11. **房地美 (FMCC) / 房利美 (FNMA):**
#     *   **新闻/观点:** 特朗普发推文表示正认真考虑让两家公司重新上市，并称它们经营状况良好。股价暴涨。
#     *   **结论:** 强烈利好 (受特朗普言论直接驱动)
#     *   **置信度:** 0.9
#     *   **分析逻辑:** 特朗普的直接表态是私有化或上市计划的重大利好信号，市场对此反应强烈。
#
# 12. **耐克 (NKE):**
#     *   **新闻/观点:** 宣布从6月1日起全面提高产品价格（$2-$10），早于白宫提及的关税恢复日期。宣布回归亚马逊平台和扩张线下零售。
#     *   **结论:** 混合 (提价应对成本/关税压力，渠道扩张是利好销售)
#     *   **置信度:** 0.7
#     *   **分析逻辑:** 提价可能反映成本上升（包括潜在关税），对销售有潜在负面影响。回归亚马逊和扩张线下渠道是积极的市场策略，旨在提升销量和消费者体验。关税政策对零售业的影响正在显现。
#
# 13. **联合健康 (UNH):**
#     *   **新闻/观点:** 受媒体爆料（否认）及美国政府扩大医保优势计划（Medicare Advantage）审计范围的消息影响，连续两天下跌。审计旨在追查不当理赔。
#     *   **结论:** 强烈利空
#     *   **置信度:** 0.9
#     *   **分析逻辑:** 政府加强对医保优势计划的监管和审计，直接针对利润来源（不当理赔），对以医保业务为主的健康险公司构成实质性利空。作者认为跌势符合技术分析中回补缺口的预期，并已卖出底部仓位，等待更低价格买回。
#
# ---
#
# **JSON 格式总结:**
#
# ```json
# [
#   {
#     "公司/行业": "整体美股市场",
#     "新闻及观点的简短总结": "昨日大跌后企稳，得益于投资者逢低买入大科技股；对美国高债务水平持续担忧，市场情绪脆弱，窄幅震荡。",
#     "结论（利好/利空）": "中性",
#     "置信度": 0.7,
#     "分析逻辑": "经济数据好于预期但不足以抵消债务担忧和降息预期降温带来的压力。"
#   },
#   {
#     "公司/行业": "美国经济数据",
#     "新闻及观点的简短总结": "美国上周初请失业金人数意外下降，5月制造业和服務业PMI初值均超预期。",
#     "结论（利好/利空）": "利好经济",
#     "置信度": 0.9,
#     "分析逻辑": "数据显示美国劳动力市场健康，经济活动加速扩张。"
#   },
#   {
#     "公司/行业": "美联储降息预期",
#     "新闻及观点的简短总结": "强劲的经济数据支持美联储推迟降息。",
#     "结论（利好/利空）": "利空降息",
#     "置信度": 0.8,
#     "分析逻辑": "经济表现坚挺降低了美联储近期降息的紧迫性，6月降息概率降低。"
#   },
#   {
#     "公司/行业": "特朗普税改法案",
#     "新闻及观点的简短总结": "众议院以微弱优势通过特朗普税改法案，延长减税，削减部分支出，增加国防/边境开支，预计增债3.8-5万亿。",
#     "结论（利好/利空）": "混合",
#     "置信度": 0.7,
#     "分析逻辑": "政策内容复杂，包含刺激和增债因素；通过过程反映政治博弈和特朗普的强力施压；增加债务是长期担忧。"
#   },
#   {
#     "公司/行业": "美国国债收益率",
#     "新闻及观点的简短总结": "受税改消息影响一度冲高后快速回落，出现大量买盘。",
#     "结论（利好/利空）": "暂时利好美债价格/利空收益率",
#     "置信度": 0.7,
#     "分析逻辑": "作者怀疑是官方（财政部/美联储）指导金融机构入场买债，以压低收益率、稳定市场，应对日本国债收益率上升带来的全球资本流动风险。"
#   },
#   {
#     "公司/行业": "日本国债收益率",
#     "新闻及观点的简短总结": "日本30/40年期国债收益率触及25年高点。",
#     "结论（利好/利空）": "利空（全球金融市场流动性）",
#     "置信度": 0.9,
#     "分析逻辑": "收益率上升可能导致资本流出美国资产回流日本平仓日元套利交易，对全球资产产生吸力，构成风险。"
#   },
#   {
#     "公司/行业": "太阳能板块 (RUN, TAN)",
#     "新闻及观点的简短总结": "前几天因税改利好预期大幅上涨，法案通过后暴跌回吐涨幅。",
#     "结论（利好/利空）": "强烈利空",
#     "置信度": 0.9,
#     "分析逻辑": "作者认为是庄家利用对政策的误读进行拉高出货，认为在当前政府下太阳能股前景不佳。"
#   },
#   {
#     "公司/行业": "Deckers Outdoor (DECK)",
#     "新闻及观点的简短总结": "财报营收/利润超预期，但本季度展望不及预期，且因关税担忧未提供全年指引，盘后大跌。",
#     "结论（利好/利空）": "强烈利空",
#     "置信度": 0.9,
#     "分析逻辑": "展望不佳和缺乏指引是负面信号，尤其关税担忧加剧了不确定性。"
#   },
#   {
#     "公司/行业": "Snowflake (SNOW)",
#     "新闻及观点的简短总结": "财报超预期，产品营收和RPO增长稳健，上调全年指引；积极招聘销售人员。股价大涨。",
#     "结论（利好/利空）": "混合",
#     "置信度": 0.7,
#     "分析逻辑": "业绩和指引是短期利好，但作者强调其过高估值、高股权稀释以及未盈利的基本面问题，认为风险较高，不宜逆势抄底。"
#   },
#   {
#     "公司/行业": "加密货币/Tokenized Equities",
#     "新闻及观点的简短总结": "比特币创历史新高。Kraken交易所计划推出美股/ETF代币化版本，允许非美国客户24/7交易。",
#     "结论（利好/利空）": "潜在利好",
#     "置信度": 0.6,
#     "分析逻辑": "理论上能提高美股全球可及性和流动性，但作者对监管能否通过表示怀疑。"
#   },
#   {
#     "公司/行业": "房地美/房利美 (FMCC/FNMA)",
#     "新闻及观点的简短总结": "特朗普发推文表示正认真考虑让它们重新上市，股价暴涨。",
#     "结论（利好/利空）": "强烈利好",
#     "置信度": 0.9,
#     "分析逻辑": "特朗普的直接政治推动是股价上涨的主要原因。"
#   },
#   {
#     "公司/行业": "耐克 (NKE)",
#     "新闻及观点的简短总结": "宣布从6月1日起提高产品价格，回归亚马逊平台并扩张线下零售。",
#     "结论（利好/利空）": "混合",
#     "置信度": 0.7,
#     "分析逻辑": "提价可能反映成本或关税压力，但渠道扩张是积极的销售策略。整体受贸易政策影响显现。"
#   },
#   {
#     "公司/行业": "联合健康 (UNH)",
#     "新闻及观点的简短总结": "受医保报销争议爆料和政府扩大医保审计范围影响，股价连续回落。",
#     "结论（利好/利空）": "强烈利空",
#     "置信度": 0.9,
#     "分析逻辑": "政府对主要业务（医保优势计划）加强监管和审计，直接打击其盈利模式，构成负面冲击。"
#   }
# ]
# ```

# %%
import os
import time
import logging
from datetime import datetime
from dataclasses import dataclass
from typing import Optional, Tuple, List, Dict, Any
from functools import wraps

from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from google import genai
from google.genai import types

# 配置日志
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f'video_analysis_{datetime.now().strftime("%Y%m%d")}.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

@dataclass
class Config:
    """配置类，统一管理所有配置项"""
    youtube_api_service_name: str = 'youtube'
    youtube_api_version: str = 'v3'
    channel_name: str = 'NaNa说美股'
    gemini_model: str = 'gemini-2.5-flash-preview-05-20'
    max_retries: int = 3
    max_videos_to_check: int = 5  # 检查多个视频以过滤直播
    
    @property
    def google_api_key(self) -> Optional[str]:
        return os.environ.get('GOOGLE_API_KEY')
    
    def validate(self) -> bool:
        """验证配置"""
        if not self.google_api_key:
            logger.error("请设置 GOOGLE_API_KEY 环境变量")
            return False
        return True

def retry_on_failure(max_retries: int = 3, delay: float = 1.0):
    """重试装饰器，支持指数退避"""
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            for attempt in range(max_retries):
                try:
                    return func(*args, **kwargs)
                except Exception as e:
                    if attempt == max_retries - 1:
                        logger.error(f"函数 {func.__name__} 在 {max_retries} 次尝试后仍然失败: {e}")
                        raise e
                    logger.warning(f"第 {attempt + 1} 次尝试失败: {e}")
                    time.sleep(delay * (2 ** attempt))  # 指数退避
            return None
        return wrapper
    return decorator

class YouTubeAnalyzer:
    """YouTube视频分析器类"""
    
    def __init__(self, config: Config):
        self.config = config
        self.youtube_service = None
        self.gemini_client = None
    
    def initialize_services(self) -> bool:
        """初始化YouTube和Gemini服务"""
        try:
            # 初始化YouTube服务
            self.youtube_service = self._get_youtube_service()
            if not self.youtube_service:
                return False
            
            # 初始化Gemini客户端
            self.gemini_client = genai.Client()
            logger.info("服务初始化成功")
            return True
            
        except Exception as e:
            logger.error(f"服务初始化失败: {e}")
            return False
    
    def _get_youtube_service(self):
        """构建并返回 YouTube 服务对象"""
        try:
            youtube = build(
                self.config.youtube_api_service_name,
                self.config.youtube_api_version,
                developerKey=self.config.google_api_key
            )
            logger.info("YouTube服务构建成功")
            return youtube
        except Exception as e:
            logger.error(f"构建 YouTube 服务时出错: {e}")
            return None
    
    @retry_on_failure(max_retries=3)
    def find_channel_id(self, channel_name: str) -> Optional[str]:
        """根据频道名称搜索并返回频道 ID"""
        if not self.youtube_service:
            logger.error("YouTube服务未初始化")
            return None
        
        try:
            search_response = self.youtube_service.search().list(
                q=channel_name,
                part='snippet',
                type='channel',
                maxResults=1
            ).execute()
            
            if not search_response.get('items'):
                logger.warning(f"未能找到名为 '{channel_name}' 的频道")
                return None
            
            channel_id = search_response['items'][0]['snippet']['channelId']
            found_channel_title = search_response['items'][0]['snippet']['title']
            logger.info(f"找到频道: '{found_channel_title}' (ID: {channel_id})")
            return channel_id
            
        except HttpError as e:
            logger.error(f"搜索频道 ID 时发生 HTTP 错误 {e.resp.status}: {e.content}")
            raise
        except Exception as e:
            logger.error(f"搜索频道 ID 时发生错误: {e}")
            raise
    
    def _is_live_content(self, video_title: str, video_snippet: Dict[str, Any]) -> bool:
        """判断是否为直播内容"""
        live_keywords = ['直播', 'live', '回放', 'replay', '实时', '盘前', '盘后']
        title_lower = video_title.lower()
        
        # 检查标题中的关键词
        for keyword in live_keywords:
            if keyword in title_lower:
                return True
        
        # 检查视频描述
        description = video_snippet.get('description', '').lower()
        for keyword in live_keywords:
            if keyword in description:
                return True
                
        return False
    
    @retry_on_failure(max_retries=3)
    def get_latest_uploaded_video_link(self, channel_id: str) -> Tuple[Optional[str], Optional[str]]:
        """获取指定频道 ID 的最新上传视频链接 (过滤直播回放)"""
        if not self.youtube_service or not channel_id:
            return None, None
        
        if not channel_id.startswith('UC'):
            logger.error(f"频道 ID '{channel_id}' 格式不正确，应该以 'UC' 开头")
            return None, None
        
        uploads_playlist_id = 'UU' + channel_id[2:]
        
        try:
            playlist_items_response = self.youtube_service.playlistItems().list(
                part='snippet,contentDetails',
                playlistId=uploads_playlist_id,
                maxResults=self.config.max_videos_to_check
            ).execute()
            
            if not playlist_items_response.get('items'):
                logger.warning(f"频道 {channel_id} 中没有找到视频")
                return None, None
            
            # 遍历视频，找到第一个非直播内容
            for item in playlist_items_response['items']:
                video_id = item['contentDetails']['videoId']
                video_title = item['snippet']['title']
                
                # 过滤直播内容
                if not self._is_live_content(video_title, item['snippet']):
                    video_url = f'https://www.youtube.com/watch?v={video_id}'
                    logger.info(f"获取到最新上传视频: '{video_title}'")
                    return video_url, video_title
            
            logger.warning("未找到非直播的上传视频")
            return None, None
            
        except HttpError as e:
            logger.error(f"获取最新上传视频时发生 HTTP 错误 {e.resp.status}: {e.content}")
            raise
        except Exception as e:
            logger.error(f"获取最新上传视频时发生错误: {e}")
            raise
    
    def _create_optimized_prompt(self) -> str:
        """创建优化的Gemini分析提示词"""
        return f"""
作为一名专业的美股分析师，请深度分析这个视频内容，重点关注以下方面：

## 分析要求：
1. **新闻事件提取**：提取视频中作者提到的每一条客观的新闻事件,并识别每条新闻事件的发生日期
2. **作者观点提取**：识别并列出作者对每一条新闻事件的所有重要观点和结论
3. **涉及美股提取**：重点分析作者每个观点中提到的美股股票，使用标准的美股股票代码，标普500使用SPY,nasdaq使用QQQ，如果作者没有提及具体股票，则填"none"，如果涉及大盘整体则填"all"
4. **股票趋势预测**：根据作者观点，预测每个股票的未来趋势，分为5类：超级看涨、看涨、中立、看跌、超级看跌
5. **影响范围**：分析每个事件和股票的影响时间范围，分为未来1～3天、未来一周、未来一个月及以上
6. **输出格式**：输出一个Json格式的列表，以新闻事件和涉及股票的组合构造每个元素，如果一条新闻事件提到了多个股票，则要拆分为多个元素，每个元素包含视频链接、博主名字、视频日期、新闻事件描述、事件日期、作者观点、股票代码、预测趋势和影响时间范围这9个字段


## 输出格式具体要求：
请严格按照以下Json格式输出分析结果，对于视频中提到的每一个事件和股票标的的组合，输出一个包含以下必填字段的字典：

{
    "results": 
        [
        {
            "video_url": "视频链接",
            "blogger_name": "博主名字",
            "video_date": "视频发布日期",
            "news_event": "新闻事件的客观描述",
            "news_event_date": "新闻事件发生的日期",
            "author_opinion": "作者对该事件和股票的具体观点",
            "stock_symbol": "作者提到的美股标准的股票代码，标普500使用SPY,nasdaq使用QQQ，如果作者没有提及则填"none",对美股全部大盘用"all"",
            "author_prediction": "5类股票趋势的预测：超级看涨、看涨、中立、看跌、超级看跌",
            "impact_timeframe": "3类影响范围：未来1～3天、未来一周、未来一个月及以上",
        },
            {
                "video_url": "视频链接",
                "blogger_name": "博主名字",
                "video_date": "视频发布日期",
                "news_event": "另一条新闻事件的客观描述",
                "news_event_date": "新闻事件发生的日期",
                "author_opinion": "作者对该事件和股票的具体观点",
                "stock_symbol": "作者提到的美股标准的股票代码，标普500使用SPY,nasdaq使用QQQ，如果作者没有提及则填"none",对美股全部大盘用"all"",
                "author_prediction": "5类股票趋势的预测：超级看涨、看涨、中立、看跌、超级看跌",
                "impact_timeframe": "3类影响范围：未来1～3天、未来一周、未来一个月及以上"
            },
            # 更多事件和股票的组合...
        ]
}
"""
    
    def analyze_video_with_gemini(self, video_url: str, video_title: str) -> Optional[str]:
        """使用Gemini分析视频内容"""
        if not self.gemini_client:
            logger.error("Gemini客户端未初始化")
            return None
        
        try:
            prompt_text = self._create_optimized_prompt()
            
            video_part = types.Part(
                file_data=types.FileData(file_uri=video_url)
            )
            prompt_part = types.Part(text=prompt_text)
            
            logger.info(f"开始分析视频: {video_title}")
            logger.info(f"视频URL: {video_url}")
            
            response = self.gemini_client.models.generate_content(
                model=self.config.gemini_model,
                contents=types.Content(parts=[video_part, prompt_part])
            )
            
            if response.candidates and response.candidates[0].content.parts:
                result = ""
                for part in response.candidates[0].content.parts:
                    result += part.text
                
                logger.info("视频分析完成")
                return result
            else:
                logger.warning("Gemini返回了空响应")
                return None
                
        except Exception as e:
            logger.error(f"调用 Gemini API 时发生错误: {e}")
            raise
    
    def save_analysis_result(self, result: str, video_title: str) -> None:
        """保存分析结果到文件"""
        try:
            timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
            filename = f"analysis_{timestamp}_{video_title[:30].replace('/', '_')}.md"
            
            with open(filename, 'w', encoding='utf-8') as f:
                f.write(f"# 视频分析报告\n\n")
                f.write(f"**视频标题**: {video_title}\n\n")
                f.write(f"**分析时间**: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
                f.write(f"**频道**: {self.config.channel_name}\n\n")
                f.write("---\n\n")
                f.write(result)
            
            logger.info(f"分析结果已保存到: {filename}")
            
        except Exception as e:
            logger.error(f"保存分析结果时发生错误: {e}")
    
    def run_analysis(self) -> bool:
        """执行完整的分析流程"""
        try:
            # 初始化服务
            if not self.initialize_services():
                return False
            
            # 查找频道ID
            channel_id = self.find_channel_id(self.config.channel_name)
            if not channel_id:
                logger.error(f"未找到频道: {self.config.channel_name}")
                return False
            
            # 获取最新视频
            video_url, video_title = self.get_latest_uploaded_video_link(channel_id)
            if not video_url or not video_title:
                logger.error("未获取到最新视频")
                return False
            # video_url = "https://www.youtube.com/watch?v=vhEvLMyKLfI" # 测试用视频链接
            # 分析视频
            analysis_result = self.analyze_video_with_gemini(video_url, video_title)
            if not analysis_result:
                logger.error("视频分析失败")
                return False
            
            # 保存结果
            self.save_analysis_result(analysis_result, video_title)
            
            # 输出结果
            print("\n" + "="*50)
            print("视频分析结果")
            print("="*50)
            print(f"频道: {self.config.channel_name}")
            print(f"视频: {video_title}")
            print(f"链接: {video_url}")
            print("-"*50)
            print(analysis_result)
            
            return True
            
        except Exception as e:
            logger.error(f"分析流程执行失败: {e}")
            return False

def main():
    """主函数"""
    # 创建配置
    config = Config()
    
    # 验证配置
    if not config.validate():
        return
    
    # 创建分析器并运行
    analyzer = YouTubeAnalyzer(config)
    success = analyzer.run_analysis()
    
    if success:
        logger.info("分析完成！")
    else:
        logger.error("分析失败，请检查日志获取详细信息")

if __name__ == '__main__':
    main()
# Out:
# ERROR:__main__:搜索频道 ID 时发生错误: timed out
# WARNING:__main__:第 1 次尝试失败: timed out
# ERROR:__main__:搜索频道 ID 时发生错误: timed out
# WARNING:__main__:第 2 次尝试失败: timed out
# ERROR:__main__:搜索频道 ID 时发生错误: timed out
# ERROR:__main__:函数 find_channel_id 在 3 次尝试后仍然失败: timed out
# ERROR:__main__:分析流程执行失败: timed out
# ERROR:__main__:分析失败，请检查日志获取详细信息
